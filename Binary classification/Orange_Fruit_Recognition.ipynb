# %% [markdown]
# ## **Import Required Libraries**

# %%
try:
    import sys,os
    import tensorflow as tf
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    print("----Libraries Loaded----")
except:
    print("----Libraries Not Loaded----")
# Out:
# ----Libraries Loaded----

# %% [markdown]
# ## **Loading, Reading, and Pre-Processing Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/My Drive/Projects/Orange-Fruit-Recognition-Using-Image-Segmentation")

# %%
os.listdir()
# Out:
# ['Binary classification',
#  'requirements.txt',
#  'README.md',
#  '.git',
#  'Image_Segmentaion',
#  'build_model.py']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1.0 / 255, 
        rotation_range=30,  
        zoom_range = 0.15,  
        width_shift_range=0.10,  
        height_shift_range=0.10,  
        horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    '/content/drive/My Drive/Projects/Orange-Fruit-Recognition-Using-Image-Segmentation/Binary classification/Dataset/train',
    target_size=(64,64),
    batch_size=10,
    class_mode='binary')

val_set = val_datagen.flow_from_directory(
    '/content/drive/My Drive/Projects/Orange-Fruit-Recognition-Using-Image-Segmentation/Binary classification/Dataset/validation',
    target_size=(64,64),
    batch_size=10,
    class_mode='binary')
# Out:
# Found 1062 images belonging to 2 classes.
# Found 526 images belonging to 2 classes.

# %% [markdown]
# ## **Building Model**

# %%
import tensorflow as tf
import keras
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Activation, Flatten  
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization,AveragePooling2D
from keras.losses import categorical_crossentropy  
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2 
from keras.utils import np_utils


def classifier_model():
    
    # initializing the sequential model
    model = Sequential()

    # adding first bolck of the model
    
    model.add(Conv2D(32, (3,3), input_shape = (64,64,3), activation = 'relu' , kernel_initializer='random_normal'))
    model.add(Conv2D(32, (3, 3), activation = 'relu', kernel_initializer = 'random_normal'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))

    # adding second block of the model
    model.add(Conv2D(64, (3,3), activation = 'relu', kernel_initializer = 'random_normal'))
    model.add(Conv2D(64, (3,3), activation = 'relu', kernel_initializer = 'random_normal'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))

    # adding third layer of the model
    model.add(Conv2D(64, (3,3), activation = 'relu', kernel_initializer = 'random_normal'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.25))

    # Flattening the model
    model.add(Flatten())

    # adding the Dense layers
    model.add(Dense(256, activation='relu' , kernel_initializer='random_normal'))
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu' , kernel_initializer='random_normal'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))

    # adding the output layer
    model.add(Dense(1, activation='sigmoid' , kernel_initializer='random_normal'))

    # model compilation + optimizer and loss function specifications.
    # opt = keras.optimizers.Adam(learning_rate=0.01)

    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

    return model


model = classifier_model()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 60, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               409856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 546,529
# Trainable params: 545,953
# Non-trainable params: 576
# _________________________________________________________________

# %% [markdown]
# **Compiling and Training Model**

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        training_set,
        steps_per_epoch=1062//20,
        epochs=200, 
        verbose=1,
        validation_data = val_set,
        validation_steps=526//20
        #callbacks=[callback]
    )
# Out:
# Epoch 1/200
# 53/53 [==============================] - 527s 10s/step - loss: 0.4360 - accuracy: 0.8132 - val_loss: 0.7159 - val_accuracy: 0.4462
# Epoch 2/200
# 53/53 [==============================] - 254s 5s/step - loss: 0.3093 - accuracy: 0.8640 - val_loss: 0.8191 - val_accuracy: 0.5269
# Epoch 3/200
# 53/53 [==============================] - 125s 2s/step - loss: 0.2280 - accuracy: 0.9151 - val_loss: 1.1390 - val_accuracy: 0.5038
# Epoch 4/200
# 53/53 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8851
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 53/53 [==============================] - 66s 1s/step - loss: 0.2771 - accuracy: 0.8851 - val_loss: 0.5517 - val_accuracy: 0.5115
# Epoch 5/200
# 53/53 [==============================] - 29s 563ms/step - loss: 0.2878 - accuracy: 0.9061 - val_loss: 0.9549 - val_accuracy: 0.4808
# Epoch 6/200
# 53/53 [==============================] - 25s 471ms/step - loss: 0.2541 - accuracy: 0.9019 - val_loss: 0.1983 - val_accuracy: 0.9423
# Epoch 7/200
# 53/53 [==============================] - 9s 176ms/step - loss: 0.2651 - accuracy: 0.9157 - val_loss: 1.0051 - val_accuracy: 0.5308
# Epoch 8/200
# 53/53 [==============================] - 11s 203ms/step - loss: 0.2238 - accuracy: 0.9245 - val_loss: 0.8722 - val_accuracy: 0.5154
# Epoch 9/200
# 53/53 [==============================] - 9s 177ms/step - loss: 0.2130 - accuracy: 0.9253 - val_loss: 0.1511 - val_accuracy: 0.9462
# Epoch 10/200
# 53/53 [==============================] - 7s 134ms/step - loss: 0.2153 - accuracy: 0.9157 - val_loss: 0.6782 - val_accuracy: 0.8154
# Epoch 11/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1927 - accuracy: 0.9253 - val_loss: 0.4522 - val_accuracy: 0.6346
# Epoch 12/200
# 53/53 [==============================] - 5s 100ms/step - loss: 0.1951 - accuracy: 0.9253 - val_loss: 0.2101 - val_accuracy: 0.9154
# Epoch 13/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1607 - accuracy: 0.9483 - val_loss: 1.1631 - val_accuracy: 0.5308
# Epoch 14/200
# 53/53 [==============================] - 6s 120ms/step - loss: 0.1779 - accuracy: 0.9340 - val_loss: 0.1853 - val_accuracy: 0.9231
# Epoch 15/200
# 53/53 [==============================] - 6s 124ms/step - loss: 0.2048 - accuracy: 0.9368 - val_loss: 0.1518 - val_accuracy: 0.9308
# Epoch 16/200
# 53/53 [==============================] - 7s 125ms/step - loss: 0.2426 - accuracy: 0.9151 - val_loss: 0.7363 - val_accuracy: 0.5808
# Epoch 17/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.1587 - accuracy: 0.9472 - val_loss: 0.9119 - val_accuracy: 0.5346
# Epoch 18/200
# 53/53 [==============================] - 6s 111ms/step - loss: 0.1803 - accuracy: 0.9321 - val_loss: 2.0507 - val_accuracy: 0.5962
# Epoch 19/200
# 53/53 [==============================] - 5s 90ms/step - loss: 0.2568 - accuracy: 0.8962 - val_loss: 0.1012 - val_accuracy: 0.9462
# Epoch 20/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.2105 - accuracy: 0.9321 - val_loss: 0.0304 - val_accuracy: 0.9962
# Epoch 21/200
# 53/53 [==============================] - 5s 104ms/step - loss: 0.1580 - accuracy: 0.9377 - val_loss: 0.0282 - val_accuracy: 0.9885
# Epoch 22/200
# 53/53 [==============================] - 7s 128ms/step - loss: 0.1689 - accuracy: 0.9349 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 23/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1560 - accuracy: 0.9464 - val_loss: 0.0355 - val_accuracy: 0.9923
# Epoch 24/200
# 53/53 [==============================] - 5s 100ms/step - loss: 0.1323 - accuracy: 0.9387 - val_loss: 0.0814 - val_accuracy: 0.9577
# Epoch 25/200
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1429 - accuracy: 0.9491 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 26/200
# 53/53 [==============================] - 6s 104ms/step - loss: 0.1725 - accuracy: 0.9509 - val_loss: 0.1036 - val_accuracy: 0.9731
# Epoch 27/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.1809 - accuracy: 0.9368 - val_loss: 0.1759 - val_accuracy: 0.9192
# Epoch 28/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.1802 - accuracy: 0.9340 - val_loss: 0.0567 - val_accuracy: 0.9923
# Epoch 29/200
# 53/53 [==============================] - 6s 118ms/step - loss: 0.1210 - accuracy: 0.9559 - val_loss: 0.4242 - val_accuracy: 0.8154
# Epoch 30/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.1873 - accuracy: 0.9464 - val_loss: 0.4242 - val_accuracy: 0.9231
# Epoch 31/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.1469 - accuracy: 0.9579 - val_loss: 0.0474 - val_accuracy: 0.9808
# Epoch 32/200
# 53/53 [==============================] - 5s 104ms/step - loss: 0.1527 - accuracy: 0.9472 - val_loss: 0.1816 - val_accuracy: 0.9231
# Epoch 33/200
# 53/53 [==============================] - 5s 97ms/step - loss: 0.1638 - accuracy: 0.9444 - val_loss: 0.1073 - val_accuracy: 0.9538
# Epoch 34/200
# 53/53 [==============================] - 5s 104ms/step - loss: 0.1283 - accuracy: 0.9540 - val_loss: 0.0769 - val_accuracy: 0.9692
# Epoch 35/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1278 - accuracy: 0.9617 - val_loss: 0.0368 - val_accuracy: 0.9923
# Epoch 36/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1279 - accuracy: 0.9598 - val_loss: 0.4795 - val_accuracy: 0.8346
# Epoch 37/200
# 53/53 [==============================] - 6s 102ms/step - loss: 0.1433 - accuracy: 0.9559 - val_loss: 0.1592 - val_accuracy: 0.9462
# Epoch 38/200
# 53/53 [==============================] - 7s 124ms/step - loss: 0.0954 - accuracy: 0.9660 - val_loss: 0.5363 - val_accuracy: 0.7846
# Epoch 39/200
# 53/53 [==============================] - 6s 122ms/step - loss: 0.1373 - accuracy: 0.9566 - val_loss: 0.0965 - val_accuracy: 0.9615
# Epoch 40/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.1009 - accuracy: 0.9579 - val_loss: 0.0303 - val_accuracy: 0.9885
# Epoch 41/200
# 53/53 [==============================] - 6s 111ms/step - loss: 0.1666 - accuracy: 0.9444 - val_loss: 0.1056 - val_accuracy: 0.9923
# Epoch 42/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1151 - accuracy: 0.9540 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 43/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0858 - accuracy: 0.9732 - val_loss: 0.0827 - val_accuracy: 0.9692
# Epoch 44/200
# 53/53 [==============================] - 6s 111ms/step - loss: 0.0761 - accuracy: 0.9828 - val_loss: 0.0302 - val_accuracy: 0.9885
# Epoch 45/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.1029 - accuracy: 0.9698 - val_loss: 0.0513 - val_accuracy: 0.9769
# Epoch 46/200
# 53/53 [==============================] - 6s 119ms/step - loss: 0.0938 - accuracy: 0.9736 - val_loss: 0.2365 - val_accuracy: 0.8692
# Epoch 47/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0887 - accuracy: 0.9698 - val_loss: 0.0464 - val_accuracy: 0.9885
# Epoch 48/200
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0806 - accuracy: 0.9736 - val_loss: 0.2385 - val_accuracy: 0.9385
# Epoch 49/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.1360 - accuracy: 0.9528 - val_loss: 0.2636 - val_accuracy: 0.9115
# Epoch 50/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.0648 - accuracy: 0.9770 - val_loss: 0.2445 - val_accuracy: 0.9500
# Epoch 51/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.1112 - accuracy: 0.9693 - val_loss: 0.1313 - val_accuracy: 0.9538
# Epoch 52/200
# 53/53 [==============================] - 5s 99ms/step - loss: 0.1240 - accuracy: 0.9521 - val_loss: 0.0442 - val_accuracy: 0.9808
# Epoch 53/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.4105 - accuracy: 0.8506 - val_loss: 0.7202 - val_accuracy: 0.6923
# Epoch 54/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.3699 - accuracy: 0.8506 - val_loss: 1.5944 - val_accuracy: 0.4923
# Epoch 55/200
# 53/53 [==============================] - 7s 125ms/step - loss: 0.2779 - accuracy: 0.8774 - val_loss: 1.2506 - val_accuracy: 0.4846
# Epoch 56/200
# 53/53 [==============================] - 5s 97ms/step - loss: 0.2924 - accuracy: 0.8736 - val_loss: 0.1884 - val_accuracy: 0.9500
# Epoch 57/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.2648 - accuracy: 0.8906 - val_loss: 0.1791 - val_accuracy: 0.9385
# Epoch 58/200
# 53/53 [==============================] - 5s 98ms/step - loss: 0.2569 - accuracy: 0.8966 - val_loss: 0.1416 - val_accuracy: 0.9538
# Epoch 59/200
# 53/53 [==============================] - 6s 113ms/step - loss: 0.2583 - accuracy: 0.8908 - val_loss: 0.1699 - val_accuracy: 0.9538
# Epoch 60/200
# 53/53 [==============================] - 6s 113ms/step - loss: 0.3019 - accuracy: 0.8849 - val_loss: 0.8989 - val_accuracy: 0.5769
# Epoch 61/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.2398 - accuracy: 0.9151 - val_loss: 1.1869 - val_accuracy: 0.5038
# Epoch 62/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.2461 - accuracy: 0.9138 - val_loss: 0.1268 - val_accuracy: 0.9692
# Epoch 63/200
# 53/53 [==============================] - 5s 95ms/step - loss: 0.2592 - accuracy: 0.9075 - val_loss: 0.1388 - val_accuracy: 0.9654
# Epoch 64/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1993 - accuracy: 0.9302 - val_loss: 0.1237 - val_accuracy: 0.9615
# Epoch 65/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.1904 - accuracy: 0.9330 - val_loss: 0.0976 - val_accuracy: 0.9692
# Epoch 66/200
# 53/53 [==============================] - 6s 123ms/step - loss: 0.2393 - accuracy: 0.9208 - val_loss: 0.3482 - val_accuracy: 0.7962
# Epoch 67/200
# 53/53 [==============================] - 6s 123ms/step - loss: 0.1543 - accuracy: 0.9528 - val_loss: 0.1098 - val_accuracy: 0.9615
# Epoch 68/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1683 - accuracy: 0.9377 - val_loss: 0.3660 - val_accuracy: 0.8192
# Epoch 69/200
# 53/53 [==============================] - 6s 106ms/step - loss: 0.1261 - accuracy: 0.9604 - val_loss: 0.0593 - val_accuracy: 0.9692
# Epoch 70/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1469 - accuracy: 0.9604 - val_loss: 1.3740 - val_accuracy: 0.5462
# Epoch 71/200
# 53/53 [==============================] - 6s 120ms/step - loss: 0.1530 - accuracy: 0.9483 - val_loss: 0.7044 - val_accuracy: 0.5846
# Epoch 72/200
# 53/53 [==============================] - 6s 119ms/step - loss: 0.1200 - accuracy: 0.9509 - val_loss: 0.1329 - val_accuracy: 0.9846
# Epoch 73/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1333 - accuracy: 0.9604 - val_loss: 0.0703 - val_accuracy: 0.9885
# Epoch 74/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.1312 - accuracy: 0.9585 - val_loss: 0.0976 - val_accuracy: 0.9692
# Epoch 75/200
# 53/53 [==============================] - 6s 118ms/step - loss: 0.0668 - accuracy: 0.9751 - val_loss: 0.0542 - val_accuracy: 0.9846
# Epoch 76/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.1596 - accuracy: 0.9415 - val_loss: 1.0301 - val_accuracy: 0.5308
# Epoch 77/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1425 - accuracy: 0.9509 - val_loss: 0.4370 - val_accuracy: 0.7885
# Epoch 78/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.1176 - accuracy: 0.9566 - val_loss: 0.1553 - val_accuracy: 0.9462
# Epoch 79/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1381 - accuracy: 0.9579 - val_loss: 0.0308 - val_accuracy: 0.9885
# Epoch 80/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.1357 - accuracy: 0.9521 - val_loss: 3.1853 - val_accuracy: 0.5577
# Epoch 81/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.1445 - accuracy: 0.9566 - val_loss: 2.5378 - val_accuracy: 0.5923
# Epoch 82/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.1323 - accuracy: 0.9483 - val_loss: 1.7458 - val_accuracy: 0.5615
# Epoch 83/200
# 53/53 [==============================] - 6s 123ms/step - loss: 0.0917 - accuracy: 0.9698 - val_loss: 0.1395 - val_accuracy: 0.9615
# Epoch 84/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.1540 - accuracy: 0.9464 - val_loss: 1.1181 - val_accuracy: 0.5923
# Epoch 85/200
# 53/53 [==============================] - 7s 124ms/step - loss: 0.0938 - accuracy: 0.9660 - val_loss: 0.4492 - val_accuracy: 0.7808
# Epoch 86/200
# 53/53 [==============================] - 7s 127ms/step - loss: 0.2334 - accuracy: 0.9310 - val_loss: 0.1201 - val_accuracy: 0.9500
# Epoch 87/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.1081 - accuracy: 0.9642 - val_loss: 0.0286 - val_accuracy: 0.9923
# Epoch 88/200
# 53/53 [==============================] - 6s 123ms/step - loss: 0.1202 - accuracy: 0.9566 - val_loss: 0.0476 - val_accuracy: 0.9885
# Epoch 89/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0759 - accuracy: 0.9732 - val_loss: 0.1946 - val_accuracy: 0.9538
# Epoch 90/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0965 - accuracy: 0.9698 - val_loss: 0.9001 - val_accuracy: 0.6846
# Epoch 91/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0964 - accuracy: 0.9770 - val_loss: 0.0409 - val_accuracy: 0.9885
# Epoch 92/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1442 - accuracy: 0.9509 - val_loss: 0.0215 - val_accuracy: 0.9923
# Epoch 93/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1138 - accuracy: 0.9713 - val_loss: 0.0517 - val_accuracy: 0.9846
# Epoch 94/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.1520 - accuracy: 0.9579 - val_loss: 0.1314 - val_accuracy: 0.9346
# Epoch 95/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1043 - accuracy: 0.9717 - val_loss: 0.0271 - val_accuracy: 0.9962
# Epoch 96/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.1083 - accuracy: 0.9598 - val_loss: 0.0513 - val_accuracy: 0.9808
# Epoch 97/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1163 - accuracy: 0.9636 - val_loss: 0.0137 - val_accuracy: 0.9962
# Epoch 98/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.1171 - accuracy: 0.9660 - val_loss: 0.0336 - val_accuracy: 0.9923
# Epoch 99/200
# 53/53 [==============================] - 5s 94ms/step - loss: 0.1004 - accuracy: 0.9717 - val_loss: 0.1950 - val_accuracy: 0.9654
# Epoch 100/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0929 - accuracy: 0.9693 - val_loss: 0.0547 - val_accuracy: 0.9885
# Epoch 101/200
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0916 - accuracy: 0.9660 - val_loss: 0.0439 - val_accuracy: 0.9885
# Epoch 102/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.1187 - accuracy: 0.9579 - val_loss: 0.0339 - val_accuracy: 0.9885
# Epoch 103/200
# 53/53 [==============================] - 6s 104ms/step - loss: 0.0812 - accuracy: 0.9755 - val_loss: 0.0223 - val_accuracy: 0.9923
# Epoch 104/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0469 - accuracy: 0.9868 - val_loss: 0.0271 - val_accuracy: 0.9923
# Epoch 105/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.1122 - accuracy: 0.9623 - val_loss: 0.0320 - val_accuracy: 0.9885
# Epoch 106/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0598 - accuracy: 0.9828 - val_loss: 0.1794 - val_accuracy: 0.9577
# Epoch 107/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0823 - accuracy: 0.9713 - val_loss: 0.0251 - val_accuracy: 0.9923
# Epoch 108/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.0733 - accuracy: 0.9736 - val_loss: 0.0334 - val_accuracy: 0.9885
# Epoch 109/200
# 53/53 [==============================] - 6s 121ms/step - loss: 0.0754 - accuracy: 0.9736 - val_loss: 0.0815 - val_accuracy: 0.9846
# Epoch 110/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1536 - accuracy: 0.9604 - val_loss: 0.0330 - val_accuracy: 0.9885
# Epoch 111/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.1090 - accuracy: 0.9617 - val_loss: 0.2810 - val_accuracy: 0.9423
# Epoch 112/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.2105 - accuracy: 0.9283 - val_loss: 0.9509 - val_accuracy: 0.5346
# Epoch 113/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.1235 - accuracy: 0.9453 - val_loss: 1.0176 - val_accuracy: 0.5615
# Epoch 114/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.1360 - accuracy: 0.9521 - val_loss: 0.7136 - val_accuracy: 0.6038
# Epoch 115/200
# 53/53 [==============================] - 5s 98ms/step - loss: 0.1050 - accuracy: 0.9717 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 116/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.1340 - accuracy: 0.9528 - val_loss: 0.0290 - val_accuracy: 0.9923
# Epoch 117/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0881 - accuracy: 0.9674 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 118/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.1049 - accuracy: 0.9642 - val_loss: 0.0189 - val_accuracy: 0.9923
# Epoch 119/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.0911 - accuracy: 0.9774 - val_loss: 0.0277 - val_accuracy: 0.9923
# Epoch 120/200
# 53/53 [==============================] - 6s 111ms/step - loss: 0.1188 - accuracy: 0.9655 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 121/200
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0914 - accuracy: 0.9736 - val_loss: 0.0254 - val_accuracy: 0.9885
# Epoch 122/200
# 53/53 [==============================] - 6s 118ms/step - loss: 0.0968 - accuracy: 0.9755 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 123/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0922 - accuracy: 0.9642 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 124/200
# 53/53 [==============================] - 5s 104ms/step - loss: 0.0869 - accuracy: 0.9751 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 125/200
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0951 - accuracy: 0.9693 - val_loss: 0.0213 - val_accuracy: 0.9923
# Epoch 126/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.1373 - accuracy: 0.9521 - val_loss: 0.1054 - val_accuracy: 0.9577
# Epoch 127/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0835 - accuracy: 0.9751 - val_loss: 0.6075 - val_accuracy: 0.8308
# Epoch 128/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.1354 - accuracy: 0.9579 - val_loss: 0.0281 - val_accuracy: 0.9885
# Epoch 129/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0917 - accuracy: 0.9585 - val_loss: 0.0296 - val_accuracy: 0.9885
# Epoch 130/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0885 - accuracy: 0.9751 - val_loss: 0.0287 - val_accuracy: 0.9923
# Epoch 131/200
# 53/53 [==============================] - 7s 127ms/step - loss: 0.0613 - accuracy: 0.9770 - val_loss: 0.0246 - val_accuracy: 0.9962
# Epoch 132/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0814 - accuracy: 0.9770 - val_loss: 0.0373 - val_accuracy: 0.9885
# Epoch 133/200
# 53/53 [==============================] - 6s 103ms/step - loss: 0.0668 - accuracy: 0.9811 - val_loss: 0.0445 - val_accuracy: 0.9885
# Epoch 134/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1153 - accuracy: 0.9623 - val_loss: 0.0150 - val_accuracy: 0.9962
# Epoch 135/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0388 - accuracy: 0.9943 - val_loss: 0.0549 - val_accuracy: 0.9846
# Epoch 136/200
# 53/53 [==============================] - 6s 104ms/step - loss: 0.0807 - accuracy: 0.9770 - val_loss: 0.0219 - val_accuracy: 0.9885
# Epoch 137/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0780 - accuracy: 0.9693 - val_loss: 0.0365 - val_accuracy: 0.9846
# Epoch 138/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0666 - accuracy: 0.9713 - val_loss: 0.0275 - val_accuracy: 0.9885
# Epoch 139/200
# 53/53 [==============================] - 6s 106ms/step - loss: 0.1479 - accuracy: 0.9636 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 140/200
# 53/53 [==============================] - 6s 111ms/step - loss: 0.1235 - accuracy: 0.9617 - val_loss: 0.0763 - val_accuracy: 0.9731
# Epoch 141/200
# 53/53 [==============================] - 6s 118ms/step - loss: 0.1228 - accuracy: 0.9585 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 142/200
# 53/53 [==============================] - 6s 113ms/step - loss: 0.1059 - accuracy: 0.9713 - val_loss: 0.0266 - val_accuracy: 0.9846
# Epoch 143/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0558 - accuracy: 0.9847 - val_loss: 0.0250 - val_accuracy: 0.9923
# Epoch 144/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0437 - accuracy: 0.9830 - val_loss: 0.0957 - val_accuracy: 0.9846
# Epoch 145/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0532 - accuracy: 0.9811 - val_loss: 0.0124 - val_accuracy: 0.9962
# Epoch 146/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.0823 - accuracy: 0.9774 - val_loss: 0.0553 - val_accuracy: 0.9808
# Epoch 147/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0601 - accuracy: 0.9828 - val_loss: 0.0835 - val_accuracy: 0.9577
# Epoch 148/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0607 - accuracy: 0.9830 - val_loss: 0.0382 - val_accuracy: 0.9962
# Epoch 149/200
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0756 - accuracy: 0.9774 - val_loss: 0.0191 - val_accuracy: 0.9962
# Epoch 150/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.0580 - accuracy: 0.9847 - val_loss: 0.0166 - val_accuracy: 0.9923
# Epoch 151/200
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0562 - accuracy: 0.9847 - val_loss: 0.0077 - val_accuracy: 0.9962
# Epoch 152/200
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0617 - accuracy: 0.9828 - val_loss: 0.0714 - val_accuracy: 0.9885
# Epoch 153/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0782 - accuracy: 0.9770 - val_loss: 0.0192 - val_accuracy: 0.9962
# Epoch 154/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.0564 - accuracy: 0.9887 - val_loss: 0.0279 - val_accuracy: 0.9923
# Epoch 155/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.1027 - accuracy: 0.9679 - val_loss: 0.0101 - val_accuracy: 0.9962
# Epoch 156/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.0655 - accuracy: 0.9811 - val_loss: 0.0279 - val_accuracy: 0.9923
# Epoch 157/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0690 - accuracy: 0.9828 - val_loss: 0.2760 - val_accuracy: 0.9077
# Epoch 158/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0921 - accuracy: 0.9655 - val_loss: 0.1269 - val_accuracy: 0.9577
# Epoch 159/200
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0993 - accuracy: 0.9636 - val_loss: 0.0359 - val_accuracy: 0.9885
# Epoch 160/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.1120 - accuracy: 0.9774 - val_loss: 0.0085 - val_accuracy: 0.9923
# Epoch 161/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0846 - accuracy: 0.9617 - val_loss: 0.0189 - val_accuracy: 0.9962
# Epoch 162/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0410 - accuracy: 0.9847 - val_loss: 0.0425 - val_accuracy: 0.9885
# Epoch 163/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0658 - accuracy: 0.9755 - val_loss: 0.0424 - val_accuracy: 0.9885
# Epoch 164/200
# 53/53 [==============================] - 6s 117ms/step - loss: 0.0417 - accuracy: 0.9868 - val_loss: 0.0239 - val_accuracy: 0.9962
# Epoch 165/200
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0425 - accuracy: 0.9868 - val_loss: 0.0432 - val_accuracy: 0.9923
# Epoch 166/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0542 - accuracy: 0.9887 - val_loss: 0.0575 - val_accuracy: 0.9923
# Epoch 167/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.1454 - accuracy: 0.9636 - val_loss: 0.0092 - val_accuracy: 0.9962
# Epoch 168/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.0281 - val_accuracy: 0.9923
# Epoch 169/200
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0440 - accuracy: 0.9849 - val_loss: 0.0359 - val_accuracy: 0.9962
# Epoch 170/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0412 - accuracy: 0.9906 - val_loss: 0.0501 - val_accuracy: 0.9846
# Epoch 171/200
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0489 - accuracy: 0.9847 - val_loss: 2.5846 - val_accuracy: 0.5615
# Epoch 172/200
# 53/53 [==============================] - 5s 104ms/step - loss: 0.3602 - accuracy: 0.8792 - val_loss: 1.1177 - val_accuracy: 0.5154
# Epoch 173/200
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1719 - accuracy: 0.9358 - val_loss: 0.0765 - val_accuracy: 0.9846
# Epoch 174/200
# 53/53 [==============================] - 6s 112ms/step - loss: 0.0928 - accuracy: 0.9642 - val_loss: 0.0232 - val_accuracy: 0.9923
# Epoch 175/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0908 - accuracy: 0.9713 - val_loss: 0.0235 - val_accuracy: 0.9923
# Epoch 176/200
# 53/53 [==============================] - 5s 101ms/step - loss: 0.1598 - accuracy: 0.9464 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 177/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.1342 - accuracy: 0.9636 - val_loss: 1.5592 - val_accuracy: 0.5308
# Epoch 178/200
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0674 - accuracy: 0.9828 - val_loss: 0.0289 - val_accuracy: 0.9885
# Epoch 179/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0460 - accuracy: 0.9866 - val_loss: 0.0514 - val_accuracy: 0.9808
# Epoch 180/200
# 53/53 [==============================] - 6s 105ms/step - loss: 0.0382 - accuracy: 0.9828 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 181/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0704 - accuracy: 0.9755 - val_loss: 0.0302 - val_accuracy: 0.9885
# Epoch 182/200
# 53/53 [==============================] - 6s 123ms/step - loss: 0.0999 - accuracy: 0.9774 - val_loss: 0.0324 - val_accuracy: 0.9846
# Epoch 183/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0855 - accuracy: 0.9774 - val_loss: 0.0735 - val_accuracy: 0.9654
# Epoch 184/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0583 - accuracy: 0.9808 - val_loss: 0.0403 - val_accuracy: 0.9846
# Epoch 185/200
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0738 - accuracy: 0.9770 - val_loss: 0.0813 - val_accuracy: 0.9923
# Epoch 186/200
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0702 - accuracy: 0.9770 - val_loss: 0.2082 - val_accuracy: 0.9654
# Epoch 187/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0586 - accuracy: 0.9792 - val_loss: 0.1192 - val_accuracy: 0.9885
# Epoch 188/200
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0817 - accuracy: 0.9828 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 189/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0605 - accuracy: 0.9789 - val_loss: 0.0111 - val_accuracy: 0.9962
# Epoch 190/200
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0654 - accuracy: 0.9849 - val_loss: 0.0056 - val_accuracy: 0.9962
# Epoch 191/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0905 - accuracy: 0.9655 - val_loss: 1.4192 - val_accuracy: 0.6423
# Epoch 192/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0670 - accuracy: 0.9774 - val_loss: 0.0438 - val_accuracy: 0.9923
# Epoch 193/200
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0430 - accuracy: 0.9906 - val_loss: 0.0311 - val_accuracy: 0.9885
# Epoch 194/200
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 195/200
# 53/53 [==============================] - 6s 119ms/step - loss: 0.0578 - accuracy: 0.9828 - val_loss: 0.0485 - val_accuracy: 0.9885
# Epoch 196/200
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0730 - accuracy: 0.9811 - val_loss: 0.0140 - val_accuracy: 0.9885
# Epoch 197/200
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0620 - accuracy: 0.9770 - val_loss: 0.0138 - val_accuracy: 0.9962
# Epoch 198/200
# 53/53 [==============================] - 6s 115ms/step - loss: 0.0847 - accuracy: 0.9713 - val_loss: 0.0181 - val_accuracy: 0.9923
# Epoch 199/200
# 53/53 [==============================] - 6s 114ms/step - loss: 0.0675 - accuracy: 0.9808 - val_loss: 0.0182 - val_accuracy: 0.9923
# Epoch 200/200
# 53/53 [==============================] - 6s 116ms/step - loss: 0.0718 - accuracy: 0.9828 - val_loss: 0.0126 - val_accuracy: 0.9962

# %% [markdown]
# **Ploting Results**

# %%
plt.plot(history.history['accuracy'][0:220])
plt.plot(history.history['val_accuracy'][0:220])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training_accuracy', 'validation_accuracy'])
plt.show()

# %%
plt.plot(history.history['loss'][0:220])
plt.plot(history.history['val_loss'][0:220])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training_loss', 'validation_loss'])
plt.show()

# %% [markdown]
# **Save Model**

# %%
m_json = model.to_json()  
with open("model2.json", "w") as json_file:  
    json_file.write(m_json)  
model.save_weights("Orange_Fruit_Weights2.h5")

# %% [markdown]
# ## **Loading and Testing Model**

# %%
from tensorflow.keras.models import load_model
from keras.models import model_from_json
from tensorflow.keras.preprocessing.image import load_img, img_to_array

model = model_from_json(open("Binary classification/model2.json", "r").read())  
model.load_weights('Binary classification/Orange_Fruit_Weights2.h5')

# %%
os.listdir('Binary classification')
# Out:
# ['Orange_Fruit_Part1.ipynb',
#  'README.md',
#  'Orange_Fruit_Weights2.h5',
#  'build_model.py',
#  'model2.json',
#  'Dataset',
#  'Images',
#  '__pycache__']

# %% [markdown]
# ## **Loading Image For Prediction**

# %%
def process_image(path):
  img = load_img(path, target_size = (64,64))
  img_tensor = img_to_array(img)
  img_tensor = np.expand_dims(img_tensor, axis = 0)
  img_tensor/=255.0
  return img_tensor

path1 = 'Binary classification/Images/Orange.jpg'
img_original1 = load_img(path1)

# %% [markdown]
# ## **Predicting**

# %%
orange=[]

pred1 = model.predict(process_image(path1))
print("Pred1 = ",pred1)
# Out:
# Pred1 =  [[0.9989064]]

# %% [markdown]
# ## **Showing Prediction Results**

# %%
def show(pred,img):

  if pred>0.5: str = '--------------Orange--------------'
  else: str = '--------------Not Orange--------------'

  plt.imshow(img)
  plt.axis('off')
  plt.title(str)
  plt.show()

show(pred1,img_original1)
#show(pred2,img_original2)

# %% [markdown]
# ## **IMAGE SEGMENTATION**

# %%
# %matplotlib inline
import cv2
import sys,os
import matplotlib
from matplotlib import colors
from matplotlib import pyplot as plt
import numpy as np
from __future__ import division

# %%
def show(image):
    # Figure size in inches
    plt.figure(figsize=(5, 5))
    # Show image, with nearest neighbour interpolation
    plt.imshow(image, interpolation='nearest')
    
def show_mask(mask):
    plt.figure(figsize=(5, 5))
    plt.imshow(mask, cmap='gray')

# %%
def find_biggest_contour(image):
    image = image.copy()
    contours, _= cv2.findContours(image, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    biggest_contour=0
    # Isolate largest contour
    contour_sizes = [(cv2.contourArea(contour), contour) for contour in contours]
    if(contour_sizes):
        a=[True]
        biggest_contour = max(contour_sizes, key=lambda x: x[0])[1]
        mask = np.zeros(image.shape, np.uint8)
        cv2.drawContours(mask, [biggest_contour], -1, 255, -1)
        return a, biggest_contour, mask
    else:
        a=[False]
        return a, biggest_contour, image

# %%
def overlay_mask(mask, image):
    # make the mask rgb
    rgb_mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB)
    # calculates the weighted sum of two arrays
    img = cv2.addWeighted(rgb_mask, 0.5, image, 0.5, 0)
    #show(img)

# %%
def segmentation(image):
  max_dimension = max(image.shape)
  scale = 700/max_dimension
  image = cv2.resize(image, None, fx=scale, fy=scale)
  
  #Convert BGR color space to RGB
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  #print("Input Image:")
  show(image)

  images = []
  for i in [0, 1, 2]:
    colour = image.copy()
    if i != 0: colour[:,:,0] = 0
    if i != 1: colour[:,:,1] = 0
    if i != 2: colour[:,:,2] = 0
    images.append(colour)
    
  #show(np.vstack(images))

  #To eliminate noise and for clean smooth colors in image.
  #Blur the image 
  image_blur = cv2.GaussianBlur(image, (7, 7), 0)
  #show(image_blur)  

  #To focus on color conert it itno HSV space. 
  image_hsv = cv2.cvtColor(image_blur, cv2.COLOR_RGB2HSV)
  #show(image_hsv)


  '''h, s, v = cv2.split(image_hsv)
  fig = plt.figure()
  axis = fig.add_subplot(1, 1, 1, projection="3d")
  pixel_colors = image.reshape((np.shape(image)[0]*np.shape(image)[1], 3))
  norm = colors.Normalize(vmin=-1.,vmax=1.)
  norm.autoscale(pixel_colors)
  pixel_colors = norm(pixel_colors).tolist()
  axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors, marker=".")
  axis.set_xlabel("Hue")
  axis.set_ylabel("Saturation")
  axis.set_zlabel("Value")
  #plt.show()'''

  # Filter by colour
  # 10-25 hue
  #minimum orange amount, max orange amount
  min_orange = np.array([10, 100, 20])
  max_orange = np.array([25, 255, 255])
  
  #layer
  mask1 = cv2.inRange(image_hsv, min_orange, max_orange)

  #birghtness of a color is hue
  # 170-180 hue
  min_orange2 = np.array([180, 100, 20])
  max_orange2 = np.array([195, 255, 255])
  mask2 = cv2.inRange(image_hsv, min_orange2, max_orange2)

  #mask capturing the orange amount
  mask = mask1 + mask2
  #print("\nSegmented Image by Color Based Detection:")
  show(mask)

  #Edge Detection using Canny
  edge=cv2.Canny(mask,50,50)
  #print("\nSegmented Image by EDGE Based Detection:")
  show(edge)

  kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))
  # Fill small gaps
  #erosion followed by dilation
  mask_closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
  
  #It is useful in removing noise
  #Dilation followed by Erosion.
  mask_clean = cv2.morphologyEx(mask_closed, cv2.MORPH_OPEN, kernel)

  a,big_orange_contour, mask_orange = find_biggest_contour(mask_clean)

  overlay = overlay_mask(mask, image) 
  
  image_with_ellipse = image.copy()
  if(any(a)):
    # Bounding ellipse
    ellipse = cv2.fitEllipse(big_orange_contour)
    cv2.ellipse(image_with_ellipse, ellipse, (0,0,0), 4)
    print("Orange Found :>")
    show(image_with_ellipse)
  else:
    print("Orange Not Found :<")
    show(image)

# %% [markdown]
# ## **Showing Segmented Image**

# %%
if pred1>0.5:
  image = cv2.imread("Binary classification/Images/Orange.jpg")
  print("Shape: {}".format(image.shape))
  segmentation(image)
else:
  print("Orange Not Found")
  show(image)
# Out:
# Shape: (563, 612, 3)
# Orange Found :>
